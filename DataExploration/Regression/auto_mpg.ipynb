# %% [markdown]
# ## Import Statements

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

# %% [markdown]
# ## Loading Data

# %%
#Load in data and display the first few rows
auto_mpg_data = pd.read_csv('../../Datasets/Regression/auto_mpg.csv')
print('Data Loaded Successfully')
display(auto_mpg_data.head())
#Note that origin is 1=USA, 2=Europe, 3=Japan

#Check Shape
num_samples = auto_mpg_data.shape[0]
num_features = auto_mpg_data.shape[1]
print('Number of Samples:', num_samples)
print('Number of Features:', num_features)
print('Data Shape:', auto_mpg_data.shape) #(Samples, Features)
# Out:
# Data Loaded Successfully
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
# Number of Samples: 398
# Number of Features: 9
# Data Shape: (398, 9)

# %% [markdown]
# ## Preprocessing Data

# %%
#Drop car name and origin column
auto_mpg_data = auto_mpg_data.drop(columns=['car name','origin'])
print('Car name & origin column dropped\n')
display(auto_mpg_data.head())

#Check for and drop null values (the null values are represented as '?')
auto_mpg_data['horsepower'] = auto_mpg_data['horsepower'].replace('?', np.nan)
auto_mpg_data = auto_mpg_data.dropna(axis=0, how='any')
num_samples_after_drop = auto_mpg_data.shape[0]
print(f'\n{num_samples - num_samples_after_drop} null containing samples dropped')
print('Number of Samples after drop:', num_samples_after_drop)
# Out:
# Car name & origin column dropped
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
# 6 null containing samples dropped
# Number of Samples after drop: 392

# %% [markdown]
# ## Examining Data

# %%
#Print all the keys in the dataset
print('Keys in the dataset:')
print(auto_mpg_data.keys(), end='\n\n')

#Display correlation matrix
corr_mat = auto_mpg_data.corr()
corr_mat = (
    corr_mat
    .style
    .background_gradient(
        cmap='coolwarm',
        vmin=-1,
        vmax=1,
        axis=None
    )
)
display(corr_mat)
# Out:
# Keys in the dataset:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year'],
#       dtype='object')
# <style type="text/css">
# #T_aa312_row0_col0, #T_aa312_row1_col1, #T_aa312_row2_col2, #T_aa312_row3_col3, #T_aa312_row4_col4, #T_aa312_row5_col5, #T_aa312_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_aa312_row0_col1, #T_aa312_row0_col3, #T_aa312_row1_col0, #T_aa312_row3_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_aa312_row0_col2, #T_aa312_row2_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_aa312_row0_col4, #T_aa312_row4_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_aa312_row0_col5, #T_aa312_row5_col0 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_aa312_row0_col6, #T_aa312_row6_col0 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_aa312_row1_col2, #T_aa312_row2_col1 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_aa312_row1_col3, #T_aa312_row3_col1 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_aa312_row1_col4, #T_aa312_row2_col3, #T_aa312_row3_col2, #T_aa312_row4_col1 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_aa312_row1_col5, #T_aa312_row5_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_aa312_row1_col6, #T_aa312_row6_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_aa312_row2_col4, #T_aa312_row4_col2 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_aa312_row2_col5, #T_aa312_row5_col2 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_aa312_row2_col6, #T_aa312_row6_col2 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_aa312_row3_col4, #T_aa312_row4_col3 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_aa312_row3_col5, #T_aa312_row5_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_aa312_row3_col6, #T_aa312_row4_col5, #T_aa312_row5_col4, #T_aa312_row6_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_aa312_row4_col6, #T_aa312_row6_col4 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_aa312_row5_col6, #T_aa312_row6_col5 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# </style>
# <table id="T_aa312">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa312_level0_col0" class="col_heading level0 col0" >mpg</th>
#       <th id="T_aa312_level0_col1" class="col_heading level0 col1" >cylinders</th>
#       <th id="T_aa312_level0_col2" class="col_heading level0 col2" >displacement</th>
#       <th id="T_aa312_level0_col3" class="col_heading level0 col3" >horsepower</th>
#       <th id="T_aa312_level0_col4" class="col_heading level0 col4" >weight</th>
#       <th id="T_aa312_level0_col5" class="col_heading level0 col5" >acceleration</th>
#       <th id="T_aa312_level0_col6" class="col_heading level0 col6" >model year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa312_level0_row0" class="row_heading level0 row0" >mpg</th>
#       <td id="T_aa312_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_aa312_row0_col1" class="data row0 col1" >-0.777618</td>
#       <td id="T_aa312_row0_col2" class="data row0 col2" >-0.805127</td>
#       <td id="T_aa312_row0_col3" class="data row0 col3" >-0.778427</td>
#       <td id="T_aa312_row0_col4" class="data row0 col4" >-0.832244</td>
#       <td id="T_aa312_row0_col5" class="data row0 col5" >0.423329</td>
#       <td id="T_aa312_row0_col6" class="data row0 col6" >0.580541</td>
#     </tr>
#     <tr>
#       <th id="T_aa312_level0_row1" class="row_heading level0 row1" >cylinders</th>
#       <td id="T_aa312_row1_col0" class="data row1 col0" >-0.777618</td>
#       <td id="T_aa312_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_aa312_row1_col2" class="data row1 col2" >0.950823</td>
#       <td id="T_aa312_row1_col3" class="data row1 col3" >0.842983</td>
#       <td id="T_aa312_row1_col4" class="data row1 col4" >0.897527</td>
#       <td id="T_aa312_row1_col5" class="data row1 col5" >-0.504683</td>
#       <td id="T_aa312_row1_col6" class="data row1 col6" >-0.345647</td>
#     </tr>
#     <tr>
#       <th id="T_aa312_level0_row2" class="row_heading level0 row2" >displacement</th>
#       <td id="T_aa312_row2_col0" class="data row2 col0" >-0.805127</td>
#       <td id="T_aa312_row2_col1" class="data row2 col1" >0.950823</td>
#       <td id="T_aa312_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_aa312_row2_col3" class="data row2 col3" >0.897257</td>
#       <td id="T_aa312_row2_col4" class="data row2 col4" >0.932994</td>
#       <td id="T_aa312_row2_col5" class="data row2 col5" >-0.543800</td>
#       <td id="T_aa312_row2_col6" class="data row2 col6" >-0.369855</td>
#     </tr>
#     <tr>
#       <th id="T_aa312_level0_row3" class="row_heading level0 row3" >horsepower</th>
#       <td id="T_aa312_row3_col0" class="data row3 col0" >-0.778427</td>
#       <td id="T_aa312_row3_col1" class="data row3 col1" >0.842983</td>
#       <td id="T_aa312_row3_col2" class="data row3 col2" >0.897257</td>
#       <td id="T_aa312_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_aa312_row3_col4" class="data row3 col4" >0.864538</td>
#       <td id="T_aa312_row3_col5" class="data row3 col5" >-0.689196</td>
#       <td id="T_aa312_row3_col6" class="data row3 col6" >-0.416361</td>
#     </tr>
#     <tr>
#       <th id="T_aa312_level0_row4" class="row_heading level0 row4" >weight</th>
#       <td id="T_aa312_row4_col0" class="data row4 col0" >-0.832244</td>
#       <td id="T_aa312_row4_col1" class="data row4 col1" >0.897527</td>
#       <td id="T_aa312_row4_col2" class="data row4 col2" >0.932994</td>
#       <td id="T_aa312_row4_col3" class="data row4 col3" >0.864538</td>
#       <td id="T_aa312_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_aa312_row4_col5" class="data row4 col5" >-0.416839</td>
#       <td id="T_aa312_row4_col6" class="data row4 col6" >-0.309120</td>
#     </tr>
#     <tr>
#       <th id="T_aa312_level0_row5" class="row_heading level0 row5" >acceleration</th>
#       <td id="T_aa312_row5_col0" class="data row5 col0" >0.423329</td>
#       <td id="T_aa312_row5_col1" class="data row5 col1" >-0.504683</td>
#       <td id="T_aa312_row5_col2" class="data row5 col2" >-0.543800</td>
#       <td id="T_aa312_row5_col3" class="data row5 col3" >-0.689196</td>
#       <td id="T_aa312_row5_col4" class="data row5 col4" >-0.416839</td>
#       <td id="T_aa312_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_aa312_row5_col6" class="data row5 col6" >0.290316</td>
#     </tr>
#     <tr>
#       <th id="T_aa312_level0_row6" class="row_heading level0 row6" >model year</th>
#       <td id="T_aa312_row6_col0" class="data row6 col0" >0.580541</td>
#       <td id="T_aa312_row6_col1" class="data row6 col1" >-0.345647</td>
#       <td id="T_aa312_row6_col2" class="data row6 col2" >-0.369855</td>
#       <td id="T_aa312_row6_col3" class="data row6 col3" >-0.416361</td>
#       <td id="T_aa312_row6_col4" class="data row6 col4" >-0.309120</td>
#       <td id="T_aa312_row6_col5" class="data row6 col5" >0.290316</td>
#       <td id="T_aa312_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Setting Target and Features

# %%
#Set the target variable
target_data = auto_mpg_data['mpg']
print('Target variable set')

#Drop the target variable from the data
auto_mpg_data = auto_mpg_data.drop(columns=['mpg'])
print('Target variable dropped from data')
# Out:
# Target variable set
# Target variable dropped from data
