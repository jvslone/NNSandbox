# %% [markdown]
# ## Import Statements

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

# %% [markdown]
# ## Loading Data

# %%
#Load in data and display the first few rows
concrete_data = pd.read_csv('../../Datasets/Regression/concrete.csv')
print('Data Loaded Successfully')
display(concrete_data.head())

#Check Shape
num_samples = concrete_data.shape[0]
num_features = concrete_data.shape[1]
print('Number of Samples:', num_samples)
print('Number of Features:', num_features)
print('Data Shape:', concrete_data.shape) #(Samples, Features)
# Out:
# Data Loaded Successfully
#    cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    coarse_aggregate  fine_aggregate   age  concrete_compressive_strength
# 0            1040.0            676.0   28                          79.99
# 1            1055.0            676.0   28                          61.89
# 2             932.0            594.0  270                          40.27
# 3             932.0            594.0  365                          41.05
# 4             978.4            825.5  360                          44.30
# Number of Samples: 1030
# Number of Features: 9
# Data Shape: (1030, 9)

# %% [markdown]
# ## Preprocessing Data

# %%
#None Needed

# %% [markdown]
# ## Examining Data

# %%
#Print all the keys in the dataset
print('Keys in the dataset:')
print(concrete_data.keys(), end='\n\n')

#Display correlation matrix
corr_mat = concrete_data.corr()
corr_mat = (
    corr_mat
    .style
    .background_gradient(
        cmap='coolwarm',
        vmin=-1,
        vmax=1,
        axis=None
    )
)
display(corr_mat)
# Out:
# Keys in the dataset:
# Index(['cement', 'blast_furnace_slag', 'fly_ash', 'water', 'superplasticizer',
#        'coarse_aggregate', 'fine_aggregate ', 'age',
#        'concrete_compressive_strength'],
#       dtype='object')
# <style type="text/css">
# #T_1ea01_row0_col0, #T_1ea01_row1_col1, #T_1ea01_row2_col2, #T_1ea01_row3_col3, #T_1ea01_row4_col4, #T_1ea01_row5_col5, #T_1ea01_row6_col6, #T_1ea01_row7_col7, #T_1ea01_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1ea01_row0_col1, #T_1ea01_row1_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_1ea01_row0_col2, #T_1ea01_row2_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_1ea01_row0_col3, #T_1ea01_row3_col0 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_1ea01_row0_col4, #T_1ea01_row4_col0 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_1ea01_row0_col5, #T_1ea01_row2_col8, #T_1ea01_row5_col0, #T_1ea01_row8_col2 {
#   background-color: #cedaeb;
# ...

# %% [markdown]
# ## Setting Target and Features

# %%
#Set the target variable
target_data = concrete_data['concrete_compressive_strength']
print('Target variable set')

#Drop the target variable from the data
auto_mpg_data = concrete_data.drop(columns=['concrete_compressive_strength'])
print('Target variable dropped from data')
# Out:
# Target variable set
# Target variable dropped from data
