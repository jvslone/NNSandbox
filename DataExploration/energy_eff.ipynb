# %% [markdown]
# ## Import Statements

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

# %% [markdown]
# ## Loading Data

# %%
#Load in data and display the first few rows
energy_eff_data = pd.read_csv('../Datasets/energy_eff.csv')
print('Data Loaded Successfully')
display(energy_eff_data.head())

#Check Shape
num_samples = energy_eff_data.shape[0]
num_features = energy_eff_data.shape[1]
print('Number of Samples:', num_samples)
print('Number of Features:', num_features)
print('Data Shape:', energy_eff_data.shape) #(Samples, Features)
# Out:
# Data Loaded Successfully
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# Number of Samples: 768
# Number of Features: 10
# Data Shape: (768, 10)

# %% [markdown]
# ## Preprocessing Data

# %%
#None Needed

# %% [markdown]
# ## Examining Data

# %%
#Print all the keys in the dataset
print('Keys in the dataset:')
print(energy_eff_data.keys(), end='\n\n')

#Display correlation matrix
corr_mat = energy_eff_data.corr()
corr_mat = (
    corr_mat
    .style
    .background_gradient(
        cmap='coolwarm',
        vmin=-1,
        vmax=1,
        axis=None
    )
)
display(corr_mat)
# Out:
# Keys in the dataset:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'Y1', 'Y2'], dtype='object')
# <style type="text/css">
# #T_908f5_row0_col0, #T_908f5_row1_col1, #T_908f5_row2_col2, #T_908f5_row3_col3, #T_908f5_row4_col4, #T_908f5_row5_col5, #T_908f5_row6_col6, #T_908f5_row7_col7, #T_908f5_row8_col8, #T_908f5_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_908f5_row0_col1, #T_908f5_row1_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_908f5_row0_col2, #T_908f5_row2_col0 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_908f5_row0_col3, #T_908f5_row3_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_908f5_row0_col4, #T_908f5_row4_col0 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ## Setting Target and Features

# %%
#Set the target variable, note that both Y1 and Y2 can be used as target variables
target_data = energy_eff_data['Y1']
print('Target variable set')

#Drop the target variable from the data
auto_mpg_data = energy_eff_data.drop(columns=['Y1','Y2'])
print('Target variable dropped from data')
# Out:
# Target variable set
# Target variable dropped from data
